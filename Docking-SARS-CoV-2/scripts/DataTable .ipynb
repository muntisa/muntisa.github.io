# %% [markdown]
# # Results to HTML table

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
import pandas as pd
import numpy as np

# %%
# get data
database = "../db/db_Publications.tab"

# %%
df = pd.read_csv(database,sep='\t', encoding='latin-1')
df.head()
# Out:
#     AE   Ligand GENERIC_NAME Target
# 0 -9.4  DB05611     Apilimod   6CS2
# 1 -9.3  DB01410  Ciclesonide   6CS2
# 2 -9.2  DB05611     Apilimod   6LZG
# 3 -9.1  DB00845  Clofazimine   6CS2
# 4 -8.8  DB00637   Astemizole   6CS2

# %%
df.shape
# Out:
# (101, 4)

# %%
#df_repurposing = df[df['Ligand'].str.startswith("DB")].sort_values(['AE']) #get only drugs
df_repurposing = df.sort_values(['AE']) # sort data on AE
df_repurposing
# Out:
#       AE   Ligand GENERIC_NAME Target
# 0   -9.4  DB05611     Apilimod   6CS2
# 1   -9.3  DB01410  Ciclesonide   6CS2
# 2   -9.2  DB05611     Apilimod   6LZG
# 3   -9.1  DB00845  Clofazimine   6CS2
# 4   -8.8  DB00637   Astemizole   6CS2
# ..   ...      ...          ...    ...
# 96  -4.6  DB00198  Oseltamivir   6lu7
# 97  -4.4  DB00608  Chloroquine   6lu7
# 98  -3.7  DB11780      Allicin   6CS2
# 99  -3.6  DB11780      Allicin   6LZG
# 100 -2.9  DB11780      Allicin   6lu7
#
# [101 rows x 4 columns]

# %%
#df_repurposing = df_repurposing[df_repurposing['AE']<=-8.5]
#df_repurposing

# %%
# print as HTML into the notebook
print(df_repurposing.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AE</th>
#       <th>Ligand</th>
#       <th>GENERIC_NAME</th>
#       <th>Target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-9.4</td>
#       <td>DB05611</td>
#       <td>Apilimod</td>
#       <td>6CS2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-9.3</td>
#       <td>DB01410</td>
#       <td>Ciclesonide</td>
#       <td>6CS2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-9.2</td>
#       <td>DB05611</td>
#       <td>Apilimod</td>
#       <td>6LZG</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-9.1</td>
#       <td>DB00845</td>
#       <td>Clofazimine</td>
#       <td>6CS2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-8.8</td>
#       <td>DB00637</td>
#       <td>Astemizole</td>
#       <td>6CS2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>-8.7</td>
# ...

# %%
# save data as HTML as external file
fout = open("../extras/publications_Table.html","w")
fout.write(df_repurposing.to_html(index=False))
fout.close()

# %%
# number of targets
len(list(set(df_repurposing['Target'])))
# Out:
# 4

# %%
# number of ligands
len(list(set(df_repurposing['Ligand'])))
# Out:
# 28

# %%
# set of targets
set(df_repurposing['Target'])
# Out:
# {'1R42', '6CS2', '6LZG', '6lu7'}
